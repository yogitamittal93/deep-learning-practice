# %% [markdown]
# <a href="https://colab.research.google.com/github/yogitamittal93/deep-learning-practice/blob/main/NLP_simpleSemanticAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
nlp=spacy.load('en_core_web_sm')

# %%
def preprocess(text):
  doc=nlp(text)
  return " ".join([
      token.lemma_.lower()
      for token in doc
      if not token.is_stop and not token.is_punct
  ])

# %%
texts=[
    "I love this product",
    'this is amazing',
    'I hate this',
    'this is terrible',
    'absolutely fantastic experience',
    'worst service ever'
]
lebels=[1, 1, 0, 0, 1, 0] #1-postive, 0-negative

# %%
cleaned_texts=[preprocess(text) for text in texts]
print(cleaned_texts)
# Out:
# ['love product', 'amazing', 'hate', 'terrible', 'absolutely fantastic experience', 'bad service']

# %%
vectorizer=TfidfVectorizer()
x=vectorizer.fit_transform(cleaned_texts)
print(x)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 10 stored elements and shape (6, 10)>
#   Coords	Values
#   (0, 6)	0.7071067811865476
#   (0, 7)	0.7071067811865476
#   (1, 1)	1.0
#   (2, 5)	1.0
#   (3, 9)	1.0
#   (4, 0)	0.5773502691896257
#   (4, 4)	0.5773502691896257
#   (4, 3)	0.5773502691896257
#   (5, 2)	0.7071067811865476
#   (5, 8)	0.7071067811865476

# %%
x_train, x_test, y_train, y_test = train_test_split(x, lebels, test_size=0.3, random_state=42, stratify=lebels)

# %%
model=LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1])

# %%
accuracy_score(y_test, model.predict(x_test))
# Out:
# 0.5

# %%
new=['amazing product']

# %%
clean=[preprocess(text) for text in new]

# %%
clean
# Out:
# ['amazing product']

# %%
vectorized=vectorizer.transform(clean)

# %%
vectorized
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2 stored elements and shape (1, 10)>

# %%
prediction=model.predict(vectorized)

# %%
prediction
# Out:
# array([1])
